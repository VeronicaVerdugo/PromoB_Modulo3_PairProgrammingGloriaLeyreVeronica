# %%
# Ejercicios
import pandas as pd

# %%
import numpy as np

# %%
# 1. Abre el fichero de rating-and-performance con el método que sea más correcto. 
# Además muestra las 5 primeras filas del DataFrame.
df = pd.read_csv("files/rating-and-performance.csv")
df[:5]
# Out:
#    index                                              title  \
# 0      0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      4  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  ...  \
# 0            EUR         100               0    3.76            54  ...
# ...

# %%
# 2. Pongamos en práctica el loc e iloc: Usando el loc:

# 2.1 Extraed todas las filas de la columna "price". ¿De qué tipo es el resultado obtenido?
df.loc[:, "price"] # Tipo float

# 2.2 Extraed todas las filas de las columnas "price" y "retail_price". ¿De qué tipo es el resultado obtenido?
df.loc [:, ["price","retail_price"]] # tipo: data frame
type(df.loc [:, ["price","retail_price"]])

# 2.3 Extraed las filas pares, de las columnas "rating", "rating_count", "rating_five_count", "rating_four_count", "rating_three_count", "rating_two_count", "rating_one_count".
df.loc[::2, ["rating", "rating_count", "rating_five_count", "rating_four_count", "rating_three_count", "rating_two_count", "rating_one_count"]]

# 2. 4 Extraed las las filas cuyo precio sea mayor que 10 y sus unidades vendidas ("units_sold") sea mayor que 5000.
df.loc[(df["price"]>10)& (df["units_sold"]>5000) , :]
# Out:
#       index                                              title  \
# 16       16  Nouvelle mode d'été pour femmes Robe sans manc...
# 77       77  Nouveau Mode Femmes Casual Shorts Costume Été ...
# 89       89  NOUVELLE Robe d'été sans manches imprimée à fl...
# 109     109  Casual femmes ras du cou à manches courtes feu...
# 111     111  Femmes classiques dos nu en dentelle évider li...
# ...     ...                                                ...
# 1533   1533  Tenues deux pièces Totem Print Femmes Sexy Dos...
# 1534   1534  Femmes Chemisier d'été Chemise Sexy Floral Che...
# 1537   1537  Plus la taille XS-7XL été femmes mode col rond...
# 1548   1548  Robe d'été surdimensionnée pour dames Robe lon...
# 1558   1558  Mode d'été pour dames Jumpsuit sans manches im...
#
#                                              title_orig  price  retail_price  \
# 16    New Summer Women's Fashion Sleeveless Polka Do...   11.0            10
# ...

# %%
# 2.2 Usando el iloc (sacaremos los mismos resultados que con el loc):

#2.5 Extraed todas las filas de la columna "price".
df.iloc[:,3]

# 2.6 Extraed todas las filas de las columnas "price" y "retail_price".
df.iloc[:,[3,4]]

# 2.7Extraed las filas pares, de las columnas "rating", "rating_count", "rating_five_count", "rating_four_count", "rating_three_count", "rating_two_count", "rating_one_count".
df.size
df.iloc[::2,8:15]
# Out:
#       rating  rating_count  rating_five_count  rating_four_count  \
# 0       3.76            54               26.0                8.0
# 2       3.57            14                5.0                4.0
# 4       3.10            20                6.0                4.0
# 6       3.84          6742             3172.0             1352.0
# 8       3.47            15                6.0                2.0
# ...      ...           ...                ...                ...
# 1564    3.38           414              156.0               58.0
# 1566    3.54            28                7.0               11.0
# 1568    4.08          1367              722.0              293.0
# 1570    3.71            59               24.0               15.0
# 1572    4.07            14                8.0                3.0
#
#       rating_three_count  rating_two_count  rating_one_count
# 0                   10.0               1.0               9.0
# 2                    2.0               0.0               3.0
# ...

# %%
# 3. Cread una nueva columna donde tengamos la diferencia entre 
# el precio al que vende el e-commerce menos el precio del minorista. 
# Insertad esta columna en la posición dos.

df.insert(1, "diferencia",(df["price"] - df["retail_price"]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/cp/gf0xm2fn59j8cbtx6jcw4fnh0000gp/T/ipykernel_4647/1593658249.py in ?()
#       1 # 3. Cread una nueva columna donde tengamos la diferencia entre
#       2 # el precio al que vende el e-commerce menos el precio del minorista.
#       3 # Insertad esta columna en la posición dos.
#       4
# ----> 5 df.insert(1, "diferencia",(df["price"] - df["retail_price"]))
#       6 df
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    4927                 "'self.flags.allows_duplicate_labels' is False."
#    4928             )
#    4929         if not allow_duplicates and column in self.columns:
#    4930             # Should this be a different kind of error??
# -> 4931             raise ValueError(f"cannot insert {column}, already exists")
# ...

# %%
df
# Out:
#       index  diferencia                                              title  \
# 0         0        2.00  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1         1      -14.00  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2         2      -35.00  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3         3        0.00  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4         4       -0.28  Femmes Shorts d'été à lacets taille élastique ...
# ...     ...         ...                                                ...
# 1568   1568       -3.00  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569   1569      -54.00  10 couleurs femmes shorts d'été lacent ceintur...
# 1570   1570      -14.00  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571   1571        2.00  Mode femmes d'été sans manches robes col en V ...
# 1572   1572        1.00  Pantalon de yoga pour femmes à la mode Slim Fi...
#
# ...

# %%
# 4. Crea una serie con nuemeros correlativos entre 1 y 12 inclusive (puedes hacerlo como lista o diccionario):

# %%
# 4.1 Cambia el indice de la serie anteriormente creada para que comience con el numero 20.

# 4.2 Nuevamente cambia el indice de la serie, esta vez con una lista que haga referencia a los meses del año (tenemos 12 elementos como la cantidad de meses del año).

# 4.3 Muestra los valores que estan en la posicion 3 y 8 de mi serie.

# 4.4 Muestra los valores que estan etiquetados en enero y agosto.

# 4.5 Muestra sus valores, indices, forma, tamaño y el tipo de elementos de la serie.
